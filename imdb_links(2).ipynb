# %%
#import libraries
#enter api key and show name as variables
#enter show search url as variable
#search for show id

# %%
import pandas as pd
import numpy as np
import json
import requests
from pandas import json_normalize
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_81/2335703180.py in <module>
#       4 import requests
#       5 from pandas import json_normalize
# ----> 6 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'bs4'

# %%
api_key = "k_793904nk/" 
show = "Wynonna Earp" 
show_search_url = "https://imdb-api.com/en/API/SearchTitle/" + api_key + show
s = requests.get(show_search_url)
s.json()
# Out:
# {'searchType': 'Title',
#  'expression': 'Wynonna Earp',
#  'results': [{'id': 'tt4878326',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BNDM1MGJhY2MtNjBhNC00Yzc0LWE5ZGUtNzY3MmNjOWE4YTM2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'Wynonna Earp',
#    'description': '(2016) (TV Series)'},
#   {'id': 'tt9159806',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BNDEwNzk4NjgtY2FmOC00YmQwLTlmZGItOWQwOTBmMTBlZDllXkEyXkFqcGdeQXVyMTU2NTA0NzM@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'Inside Wynonna Earp: Winds of Change',
#    'description': '(2018) (Short)'},
#   {'id': 'tt9159876',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BOWIyMjBhODktZmE1ZC00MDkyLWFhNjctNmZjYzEwZTg1Yzc4XkEyXkFqcGdeQXVyMTU2NTA0NzM@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'Inside Wynonna Earp: Frenemies',
#    'description': '(2018) (Short)'}],
#  'errorMessage': ''}

# %%
json_normalize(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_81/1554084498.py in <module>
# ----> 1 json_normalize(s)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# AttributeError: 'bytes' object has no attribute 'values'
